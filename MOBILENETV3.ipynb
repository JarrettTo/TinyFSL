# %%
pip install tensorflow
# Out:
# ...
#
#   Obtaining dependency information for tensorflow from https://files.pythonhosted.org/packages/93/21/9b035a4f823d6aee2917c75415be9a95861ff3d73a0a65e48edbf210cec1/tensorflow-2.15.0-cp311-cp311-win_amd64.whl.metadata
# ...
#   Obtaining dependency information for tensorflow-intel==2.15.0 from https://files.pythonhosted.org/packages/4c/48/1a5a15517f18eaa4ff8d598b1c000300b20c1bb0e624539d702117a0c369/tensorflow_intel-2.15.0-cp311-cp311-win_amd64.whl.metadata
# ...
#   Obtaining dependency information for absl-py>=1.0.0 from https://files.pythonhosted.org/packages/a2/ad/e0d3c824784ff121c03cc031f944bc7e139a8f1870ffd2845cc2dd76f6c4/absl_py-2.1.0-py3-none-any.whl.metadata
# ...
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# ...
#   Obtaining dependency information for flatbuffers>=23.5.26 from https://files.pythonhosted.org/packages/6f/12/d5c79ee252793ffe845d58a913197bfa02ae9a0b5c9bc3dc4b58d477b9e7/flatbuffers-23.5.26-py2.py3-none-any.whl.metadata
# ...

# %%
from tensorflow.keras.applications import MobileNetV3Small, MobileNetV3Large
# Out:
# WARNING:tensorflow:From C:\Users\loben\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
model = MobileNetV3Small(weights='imagenet', include_top=False)
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not 224. Weights for input shape (224, 224) will be loaded as the default.
# WARNING:tensorflow:From C:\Users\loben\anaconda3\Lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# WARNING:tensorflow:From C:\Users\loben\anaconda3\Lib\site-packages\keras\src\layers\normalization\batch_normalization.py:979: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# ...
# 4334752/4334752 [==============================] - 5s 1us/step

# %%
from tensorflow.keras import layers, models

# Add custom layers
x = layers.GlobalAveragePooling2D()(model.output)
x = layers.Dense(1024, activation='relu')(x)
outputs = layers.Dense(num_classes, activation='softmax')(x)

# Create the complete model
slt_model = models.Model(model.input, outputs)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 6
#       4 x = layers.GlobalAveragePooling2D()(model.output)
#       5 x = layers.Dense(1024, activation='relu')(x)
# ----> 6 outputs = layers.Dense(num_classes, activation='softmax')(x)
#       8 # Create the complete model
#       9 slt_model = models.Model(model.input, outputs)
#
# NameError: name 'num_classes' is not defined

# %%
slt_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 slt_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
#
# NameError: name 'slt_model' is not defined

# %%
slt_model.fit(train_data, epochs=num_epochs, validation_data=val_data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 slt_model.fit(train_data, epochs=num_epochs, validation_data=val_data)
#
# NameError: name 'slt_model' is not defined
